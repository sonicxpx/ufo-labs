# %% [markdown]
# ## UFO Sightings Evaluation and Optimization
#
#
# 1. [Create and train our "optimized" model (Linear Learner)](#1.-Create-and-train-our-%22optimized%22-model-(Linear-Learner))
# 1. Compare the results!

# %%
#Import all the needed libraries.

import pandas as pd
import numpy as np
from datetime import datetime


import boto3
from sagemaker import get_execution_role
import sagemaker

# %%
#pre-requisites: create S3 bucket, upload files, set IAM roles for Sagemaker to access to S3 bucket
role = get_execution_role()
bucket = 'sagemaker-ml-lab-tx'

# %% [markdown]
# ---
#
# ### 1. Create and train our "optimized" model (Linear Learner)
#
# Hyperparameter Tuning

# %%
#get the recordIO file for the training data that is in S3
train_file = 'ufo_sightings_train_recordIO_protobuf.data'
training_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_train/{}'.format(bucket, train_file)
print('The Pipe mode recordIO protobuf training data: {}'.format(training_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf training data: s3://sagemaker-ml-lab-tx/algorithms_lab/linearlearner_train/ufo_sightings_train_recordIO_protobuf.data

# %%
#get the recordIO file for the validation data that is in S3
validation_file = 'ufo_sightings_validatioin_recordIO_protobuf.data'
validate_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_validation/{}'.format(bucket, validation_file)
print('The Pipe mode recordIO protobuf validation data: {}'.format(validate_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf validation data: s3://sagemaker-ml-lab-tx/algorithms_lab/linearlearner_validation/ufo_sightings_validatioin_recordIO_protobuf.data

# %% [markdown]
# #

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker

container = get_image_uri(boto3.Session().region_name, 'linear-learner', "1")

# %% [markdown]
# Let's create a job and use the optimzed hyperparamters.

# %%
# Create a training job name
job_name = 'ufo-linear-learner-job-optimized-{}'.format(datetime.now().strftime("%Y%m%d%H%M%S"))
print('Here is the job name {}'.format(job_name))

# Here is where the model-artifact will be stored
output_location = 's3://{}/optimization_evaluation_lab/linearlearner_optimized_output'.format(bucket)
# Out:
# Here is the job name ufo-linear-learner-job-optimized-20200405091708

# %%
# %%time
sess = sagemaker.Session()

# Setup the LinearLeaner algorithm from the ECR container
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess,
                                       input_mode='Pipe')
# Setup the hyperparameters
linear.set_hyperparameters( feature_dim=22, 
                            predictor_type='multiclass_classifier',
                            num_classes=3,
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here
                            ## enter optimized hyperparameters here)
                          )


# Launch a training job. This method calls the CreateTrainingJob API call
data_channels = {
    'train': training_recordIO_protobuf_location,
    'validation': validate_recordIO_protobuf_location
}
linear.fit(data_channels, job_name=job_name)
# Out:
# 2020-04-05 09:17:16 Starting - Starting the training job...
# 2020-04-05 09:17:18 Starting - Launching requested ML instances......
# 2020-04-05 09:18:20 Starting - Preparing the instances for training......
# 2020-04-05 09:19:33 Downloading - Downloading input data...
# 2020-04-05 09:20:13 Training - Training image download completed. Training in progress.
# 2020-04-05 09:20:13 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/05/2020 09:20:05 INFO 140377241651008] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [04/05/2020 09:20:05 INFO 140377241651008] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'22', u'predictor_type': u'multiclass_classifier', u'num_classes': u'3'}
# [04/05/2020 09:20:05 INFO 140377241651008] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'22', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'3', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [04/05/2020 09:20:05 WARNING 140377241651008] Loggers have already been setup.
# Process 1 is a worker.
# [04/05/2020 09:20:05 INFO 140377241651008] Using default worker.
# [04/05/2020 09:20:05 INFO 140377241651008] Checkpoint loading and saving are disabled.
# [04/05/2020 09:20:05 INFO 140377241651008] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [04/05/2020 09:20:05 INFO 140377241651008] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [2020-04-05 09:20:05.712] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-04-05 09:20:05.755] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 47, "num_examples": 1, "num_bytes": 132000}
# [04/05/2020 09:20:05 INFO 140377241651008] Create Store: local
# [2020-04-05 09:20:05.994] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 237, "num_examples": 11, "num_bytes": 1452000}
# [04/05/2020 09:20:05 INFO 140377241651008] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fabca698d10>
# [04/05/2020 09:20:05 INFO 140377241651008] Scaling model computed with parameters:
#  {'stdev_weight':
# [28.581646    2.88803     9.812443   38.477737    0.36007512  0.27269545
#   0.38418746  0.3173691   0.3776962   0.35733855  0.35255855  0.32142028
#   0.32644397  0.10430246  0.4735242   0.4696843   0.28838322  0.10806718
#   0.10344636  0.22475755  0.29359126  0.23408695]
# <NDArray 22 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [ 5.0484726e+01  5.5138183e+00  3.7848587e+01 -8.7009621e+01
#   1.5309091e-01  8.0909096e-02  1.8000001e-01  1.1363637e-01
#   1.7236364e-01  1.5027274e-01  1.4545454e-01  1.1700000e-01
#   1.2127273e-01  1.1000000e-02  3.3945453e-01  3.2854545e-01
#   9.1545455e-02  1.1818182e-02  1.0818182e-02  5.3363636e-02
#   9.5272727e-02  5.8181819e-02]
# <NDArray 22 @cpu(0)>}
# [04/05/2020 09:20:06 INFO 140377241651008] nvidia-smi took: 0.0251970291138 secs to identify 0 gpus
# [04/05/2020 09:20:06 INFO 140377241651008] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 12, "sum": 12.0, "min": 12}, "Total Records Seen": {"count": 1, "max": 12000, "sum": 12000.0, "min": 12000}, "Max Records Seen Between Resets": {"count": 1, "max": 11000, "sum": 11000.0, "min": 11000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1586078406.161088, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1586078406.161056}
#
# [2020-04-05 09:20:06.667] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 505, "num_examples": 15, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5825361894880022, "sum": 0.5825361894880022, "min": 0.5825361894880022}}, "EndTime": 1586078406.667284, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1

#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5768730563762426, "sum": 0.5768730563762426, "min": 0.5768730563762426}}, "EndTime": 1586078411.022586, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022569}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.21616374283138132, "sum": 0.21616374283138132, "min": 0.21616374283138132}}, "EndTime": 1586078411.022644, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022628}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3695228090409969, "sum": 0.3695228090409969, "min": 0.3695228090409969}}, "EndTime": 1586078411.022702, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022685}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.21354186460922078, "sum": 0.21354186460922078, "min": 0.21354186460922078}}, "EndTime": 1586078411.022759, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022743}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2941395371765722, "sum": 0.2941395371765722, "min": 0.2941395371765722}}, "EndTime": 1586078411.022797, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022788}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.1884811926345266, "sum": 0.1884811926345266, "min": 0.1884811926345266}}, "EndTime": 1586078411.02285, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022834}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.1908772054931503, "sum": 0.1908772054931503, "min": 0.1908772054931503}}, "EndTime": 1586078411.022907, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022892}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.18874592789135206, "sum": 0.18874592789135206, "min": 0.18874592789135206}}, "EndTime": 1586078411.022964, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.022947}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.22492755474643525, "sum": 0.22492755474643525, "min": 0.22492755474643525}}, "EndTime": 1586078411.023021, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.023006}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.18797077624325825, "sum": 0.18797077624325825, "min": 0.18797077624325825}}, "EndTime": 1586078411.023077, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.023062}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.357962154898345, "sum": 0.357962154898345, "min": 0.357962154898345}}, "EndTime": 1586078411.023134, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078411.023119}
#
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, epoch=7, validation multiclass_cross_entropy_objective <loss>=0.198718970869
# [04/05/2020 09:20:11 INFO 140377241651008] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=multiclass_cross_entropy_objective, value=0.187970776243
# [04/05/2020 09:20:11 INFO 140377241651008] Early stop condition met. Stopping training.
# [04/05/2020 09:20:11 INFO 140377241651008] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "Number of Batches Since Last Reset": {"count": 1, "max": 15, "sum": 15.0, "min": 15}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 132, "sum": 132.0, "min": 132}, "Total Records Seen": {"count": 1, "max": 127440, "sum": 127440.0, "min": 127440}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1586078411.024031, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 7}, "StartTime": 1586078410.504146}
#
# [04/05/2020 09:20:11 INFO 140377241651008] #throughput_metric: host=algo-1, train throughput=27749.301254 records/second
# [04/05/2020 09:20:11 WARNING 140377241651008] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/05/2020 09:20:11 WARNING 140377241651008] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-04-05 09:20:11.122] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 26, "duration": 82, "num_examples": 2, "num_bytes": 234036}
# [04/05/2020 09:20:11 INFO 140377241651008] #early_stopping_criteria_metric: host=algo-1, epoch=7, criteria=multiclass_cross_entropy_objective, value=0.187970776243
# [2020-04-05 09:20:11.164] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 28, "duration": 31, "num_examples": 2, "num_bytes": 234036}
# [04/05/2020 09:20:11 INFO 140377241651008] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.18633107606529584)
# [04/05/2020 09:20:11 INFO 140377241651008] #validation_score (algo-1) : ('multiclass_accuracy', 0.9469825155104343)
# [04/05/2020 09:20:11 INFO 140377241651008] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [04/05/2020 09:20:11 INFO 140377241651008] #validation_score (algo-1) : ('dcg', 0.9777743559534511)
# [04/05/2020 09:20:11 INFO 140377241651008] #validation_score (algo-1) : ('macro_recall', 0.9270529)
# [04/05/2020 09:20:11 INFO 140377241651008] #validation_score (algo-1) : ('macro_precision', 0.904912)
# [04/05/2020 09:20:11 INFO 140377241651008] #validation_score (algo-1) : ('macro_f_1.000', 0.91508794)
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.186331076065
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.94698251551
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=1.0
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, validation dcg <score>=0.977774355953
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, validation macro_recall <score>=0.927052915096
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, validation macro_precision <score>=0.904911994934
# [04/05/2020 09:20:11 INFO 140377241651008] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.915087938309
# [04/05/2020 09:20:11 INFO 140377241651008] Best model found for hyperparameters: {"lr_scheduler_step": 153, "wd": 0.0020367449461466797, "optimizer": "adam", "lr_scheduler_factor": 0.9895518165671255, "l1": 0.3730851993396367, "learning_rate": 0.03578924546103785, "lr_scheduler_minimum_lr": 2.294182951069527e-05}
# [04/05/2020 09:20:11 INFO 140377241651008] Saved checkpoint to "/tmp/tmpV3iIRA/mx-mod-0000.params"
# [04/05/2020 09:20:11 INFO 140377241651008] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 5567.52610206604, "sum": 5567.52610206604, "min": 5567.52610206604}, "finalize.time": {"count": 1, "max": 156.9499969482422, "sum": 156.9499969482422, "min": 156.9499969482422}, "initialize.time": {"count": 1, "max": 434.27014350891113, "sum": 434.27014350891113, "min": 434.27014350891113}, "check_early_stopping.time": {"count": 9, "max": 1.0311603546142578, "sum": 4.845142364501953, "min": 0.18286705017089844}, "setuptime": {"count": 1, "max": 29.07419204711914, "sum": 29.07419204711914, "min": 29.07419204711914}, "update.time": {"count": 8, "max": 680.2527904510498, "sum": 4858.994722366333, "min": 519.6900367736816}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1586078411.192625, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1586078405.706959}
# 2020-04-05 09:20:20 Completed - Training job completed
# Training seconds: 47
# Billable seconds: 47
# CPU times: user 592 ms, sys: 30.1 ms, total: 622 ms
# Wall time: 3min 42s

# %% [markdown]
# Now we can compare the amount of time billed and the accuracy compared to our baseline model.
